# %% [markdown]
# # Notebook to read txt files taken from simulation (McStas) and create images

# %%
import skimage
import os
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage import img_as_uint
import astropy
# %matplotlib notebook

# %%
import warnings; warnings.simplefilter('ignore')

# %%
path_in = '/data/data1/BB_data/BB_simulated_tomographies/tomo'
path_out = '/data/data1/BB_data/BB_simulated_tomographies/tomo'
#not used fornow

# %%
for i in range(0,4):
    
    file_object  = open('/data/data1/BB_data/BB_simulated_tomographies/open_beam_BB/{0}/sample_camera.dat'.format(i), 'read')
  
    myfile = file_object.read()
    id_start = myfile.find('I:')+3
    id_end = myfile.find('# Error')-1
    mytxtimag = myfile[id_start:id_end]
    file_object.close()
    splitted = mytxtimag.split()
    myimg = np.zeros((1024,1024))

    v=0;

    for row in range(0,1024):
        for col in range(0,1024):
    #     print(pixel)
            myimg[row][col] = round(float(splitted[v]))
#             print(np.uint16(float(splitted[v])+0.5))
            v=v+1
    
    myi = myimg.astype('uint16')        

    io.imsave('/data/data1/BB_data/BB_simulated_tomographies/openbeams_BB/ob{:04d}.tiff'.format(i), myi)

# %%
for i in range(0,4):
    

    file_object  = open('/data/data1/BB_data/BB_simulated_tomographies/open_beam_no_BB/{0}/sample_camera.dat'.format(i), 'read')  
    myfile = file_object.read()
    id_start = myfile.find('I:')+3
    id_end = myfile.find('# Error')-1
    mytxtimag = myfile[id_start:id_end]
    file_object.close()
    splitted = mytxtimag.split()
    myimg = np.zeros((1024,1024))

    v=0;

    for row in range(0,1024):
        for col in range(0,1024):
    #     print(pixel)
            myimg[row][col] = round(float(splitted[v]))
#             print(np.uint16(float(splitted[v])+0.5))
            v=v+1
    
    myi = myimg.astype('uint16')        

    io.imsave('/data/data1/BB_data/BB_simulated_tomographies/openbeams/ob{:04d}.tiff'.format(i), myi)

# %%
for i in range(0,626):
    
    
    file_object  = open('/data/data1/BB_data/BB_simulated_tomographies/tomo/{0}/sample_camera.dat'.format(i), 'read')
  
    myfile = file_object.read()
    id_start = myfile.find('I:')+3
    id_end = myfile.find('# Error')-1
    mytxtimag = myfile[id_start:id_end]
    file_object.close()
    splitted = mytxtimag.split()
    myimg = np.zeros((1024,1024))

    v=0;

    for row in range(0,1024):
        for col in range(0,1024):
    #     print(pixel)
            myimg[row][col] = round(float(splitted[v]))
#             print(np.uint16(float(splitted[v])+0.5))
            v=v+1
    
    myi = myimg.astype('uint16')        
    io.imsave('/data/data1/BB_data/BB_simulated_tomographies/projections_BB/slice{:04d}.tiff'.format(i), myi)

# %%
for i in range(1,626):
    
    

    file_object  = open('/data/data1/BB_data/BB_simulated_tomographies/tomo_no_BB/{0}/sample_camera.dat'.format(i), 'read')

    myfile = file_object.read()
    id_start = myfile.find('I:')+3
    id_end = myfile.find('# Error')-1
    mytxtimag = myfile[id_start:id_end]
    file_object.close()
    splitted = mytxtimag.split()
    myimg = np.zeros((1024,1024))

    v=0;

    for row in range(0,1024):
        for col in range(0,1024):
    #     print(pixel)
            myimg[row][col] = round(float(splitted[v]))
#             print(np.uint16(float(splitted[v])+0.5))
            v=v+1
    
    myi = myimg.astype('uint16')        
    io.imsave('/data/data1/BB_data/BB_simulated_tomographies/projections/slice{:04d}.tiff'.format(i), myi)

# %%
for i in range(1,626):
    

    file_object  = open('/data/data1/BB_data/BB_simulated_tomographies/tomo_no_BB/{0}/transmission_camera.dat'.format(i), 'read')

    myfile = file_object.read()
    id_start = myfile.find('I:')+3
    id_end = myfile.find('# Error')-1
    mytxtimag = myfile[id_start:id_end]
    file_object.close()
    splitted = mytxtimag.split()
    myimg = np.zeros((1024,1024))

    v=0;

    for row in range(0,1024):
        for col in range(0,1024):
    #     print(pixel)
            myimg[row][col] = round(float(splitted[v]))
#             print(np.uint16(float(splitted[v])+0.5))
            v=v+1
    
    myi = myimg.astype('uint16')        

    io.imsave('/data/data1/BB_data/BB_simulated_tomographies/projections_transmission/slice{:04d}.tiff'.format(i), myi)
# Out:
# /home/carminati_c/anaconda2/lib/python2.7/site-packages/skimage/io/_io.py:132: UserWarning: /data/data1/BB_data/BB_simulated_tomographies/projections_transmission/slice0625.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
myimg.shape
io.imshow(myimg)
# Out:
# /home/carminati_c/anaconda2/lib/python2.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# <img src="data:image/png;base64,...">
