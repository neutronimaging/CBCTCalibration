# %% [markdown]
# # Ways to set the font sizes in matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting global font sizes

# %%
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 30

plt.rc('font',   size      = SMALL_SIZE  )  # controls default text sizes
plt.rc('axes',   titlesize = SMALL_SIZE  )  # fontsize of the axes title
plt.rc('axes',   labelsize = MEDIUM_SIZE )  # fontsize of the x and y labels
plt.rc('xtick',  labelsize = SMALL_SIZE  )  # fontsize of the tick labels
plt.rc('ytick',  labelsize = SMALL_SIZE  )  # fontsize of the tick labels
plt.rc('legend', fontsize  = SMALL_SIZE  )  # legend fontsize
plt.rc('figure', titlesize = BIGGER_SIZE )  # fontsize of the figure title

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))

ax[0].imshow(np.random.normal(size=[100,100]));
ax[0].set_title('Random');
ax[0].set_xlabel('x pos');
ax[0].set_ylabel('y pos');

x = np.linspace(0,1,100)
ax[1].plot(x,np.sin(x*np.pi*4), label='sine')
ax[1].plot(x,np.cos(x*np.pi*4), label='cosine')
ax[1].legend();
ax[1].set_title('Sines');
ax[1].set_xlabel('x pos');
ax[1].set_ylabel('y pos');

# %% [markdown]
# ## Setting font sizes individually

# %%
fig, ax = plt.subplots(1,2,figsize=(15,5))

ax[0].imshow(np.random.normal(size=[100,100]));
ax[0].set_title('Random', fontsize=10);
ax[0].set_xlabel('x pos',fontsize=BIGGER_SIZE);
ax[0].set_ylabel('y pos',fontsize=SMALL_SIZE);

x = np.linspace(0,1,100)
ax[1].plot(x,np.sin(x*np.pi*4), label='sine')
ax[1].plot(x,np.cos(x*np.pi*4), label='cosine')
ax[1].legend(fontsize=MEDIUM_SIZE);
ax[1].set_title('Sines', fontsize=BIGGER_SIZE);
ax[1].set_xlabel('x pos',fontsize=BIGGER_SIZE*0.5);
ax[1].set_ylabel('y pos',fontsize=SMALL_SIZE);
